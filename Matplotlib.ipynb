# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
a = np.arange(40,50)
b = np.arange(50,60)

# %%
#ploting scatter plot

plt.scatter(x, y, c='b')
plt.xlabel("X axis")
plt.ylabel("y axis")
plt.title("Graph in 2d")
plt.savefig('plot1.png')
plt.show()

# %%
plt.plot(x,y)

# %%
y = x *x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r',linestyle='dashed',linewidth=2)

# %%
plt.plot(x,y,'g*',linestyle='dashed',linewidth=2, markersize=12)

# %%
plt.plot(x,y,'ro--')

# %%
## Creating subplots

plt.subplot(3,2,1)
plt.plot(x,y,'g')
plt.subplot(3,2,2)
plt.plot(x,y,'b')
plt.subplot(3,2,3)
plt.plot(x,y,'r')
plt.subplot(3,2,4)
plt.plot(x,y,'y')
plt.subplot(3,2,5)
plt.plot(x,y,'o-')

# %%
#pi value 
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'b') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(x2, y2, color = 'g')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) # by default it has 20 bins
plt.title("histogram") 
plt.show()

# %%
plt.hist(a, bins=20)
# Out:
# (array([2., 1., 0., 1., 1., 1., 1., 0., 0., 1., 0., 2., 2., 0., 0., 0., 1.,
#         0., 1., 1.]),
#  array([ 5. ,  9.1, 13.2, 17.3, 21.4, 25.5, 29.6, 33.7, 37.8, 41.9, 46. ,
#         50.1, 54.2, 58.3, 62.4, 66.5, 70.6, 74.7, 78.8, 82.9, 87. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### Boxplot

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]


plt.boxplot(data,vert=True,patch_artist=False)

# %%
plt.boxplot(data);

# %%
plt.boxplot(data,vert=True,patch_artist=True);

# %%
plt.boxplot(data,vert=False,patch_artist=True);

# %% [markdown]
# ### Pie chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210] #calculate cumulative and then find percentage of each value 
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.2, 0, 0, 0.1)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False) 
#whatever slich we are making then the format will be choosen - float point percentage

plt.axis('equal')
plt.show()
